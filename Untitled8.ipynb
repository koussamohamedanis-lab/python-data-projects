# %%
from nltk import sent_tokenize, word_tokenize
sent = "i went to the beach. This summer is hot. "
print (word_tokenize(sent))
print (sent_tokenize(sent))
# Out:
# ['i', 'went', 'to', 'the', 'beach', '.', 'This', 'summer', 'is', 'hot', '.']
# ['i went to the beach.', 'This summer is hot.']

# %%
from nltk import PorterStemmer
porter=PorterStemmer()
print(porter.stem("sleep"))
print(porter.stem("sleeping"))
print(porter.stem("played"))
print(porter.stem("gaming"))
# Out:
# sleep
# sleep
# psleep
# play
# game

# %%
from nltk import PorterStemmer

nisso=PorterStemmer()
print("output",nisso.stem("Communication"))
# Out:
# output commun

# %%
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk import pos_tag
from nltk import word_tokenize

text = "CERIST is a research center "
tokenized_text = word_tokenize(text)
tags = pos_tag(tokenized_text)
tags
# Out:
# [('CERIST', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('research', 'NN'),
#  ('center', 'NN')]

# %%
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk

# Sample text
text = "Steve Jobs was the CEO of Apple Inc."

# Tokenize the text
tokens = word_tokenize(text)

# Perform POS tagging
tagged = pos_tag(tokens)

# Perform named entity recognition (NER)
entities = ne_chunk(tagged)

# Print named entities
for entity in entities:
    print(entity)
# Out:
# (PERSON Steve/NNP)
# (PERSON Jobs/NNP)
# ('was', 'VBD')
# ('the', 'DT')
# (ORGANIZATION CEO/NNP)
# ('of', 'IN')
# (PERSON Apple/NNP Inc/NNP)
# ('.', '.')

# %%
from IPython.display import clear_output

# !pip install spacy    # install spacy library


clear_output()     # clear the unnecessary output if you want

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import spacy
#       2 nlp = spacy.load("en_core_web_sm")
#
# ModuleNotFoundError: No module named 'spacy'

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import spacy
nlp = spacy.load("fr_core_news_sm")
import fr_core_news_sm
nlp = fr_core_news_sm.load()
doc = nlp("C'est une phrase.")
print([(w.text, w.pos_) for w in doc])
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 2
#       1 import spacy
# ----> 2 nlp = spacy.load("fr_core_news_sm")
#       3 import fr_core_news_sm
#       4 nlp = fr_core_news_sm.load()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
# ...
