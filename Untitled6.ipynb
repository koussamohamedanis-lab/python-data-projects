# %%
import pandas as pd 

pd.DataFrame({"yes":[18,1999] ,"no":[1888,555]})
# Out:
#     yes    no
# 0    18  1888
# 1  1999   555

# %%
import pandas as pd 

pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.'], "yes":[18,1999] ,"no":[1888,555]})
# Out:
#              Bob           Sue   yes    no
# 0    I liked it.  Pretty good.    18  1888
# 1  It was awful.        Bland.  1999   555

# %%
import pandas as pd

pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
