# %%
from textblob import TextBlob

wiki = TextBlob("Python is a high-level, general-purpose programming language.")
wiki.tags
# Out:
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN')]

# %%
wiki.tags
# Out:
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN')]

# %%
wiki.noun_phrases
# Out:
# WordList(['python'])

# %%
testimonial = TextBlob("happy happy happy")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.8000000000000002, subjectivity=1.0)

# %%
zen = TextBlob(
    "Beautiful is better than ugly. "
    "Explicit is better than implicit. "
    "Simple is better than complex."
)
print('Word list: ',zen.words, '\n')

print('Sentence list: ',zen.sentences)
# Out:
# Word list:  ['Beautiful', 'is', 'better', 'than', 'ugly', 'Explicit', 'is', 'better', 'than', 'implicit', 'Simple', 'is', 'better', 'than', 'complex']
#
# Sentence list:  [Sentence("Beautiful is better than ugly."), Sentence("Explicit is better than implicit."), Sentence("Simple is better than complex.")]

# %%
animals = TextBlob("cat dog octopus")
print(animals.words)

print(animals.words.pluralize())
# Out:
# ['cat', 'dog', 'octopus']
# ['cats', 'dogs', 'octopodes']

# %%
b = TextBlob("I havv goood  speling!")
b.correct()
# Out:
# TextBlob("I have good  spelling!")

# %%
from textblob import Word

w = Word('correcte')
w.spellcheck()
# Out:
# [('correct', 0.7169811320754716),
#  ('corrected', 0.2641509433962264),
#  ('corrects', 0.018867924528301886)]

# %%
monty = TextBlob("We are no longer the Knights who say Ni. "
                    "We are old now the Knights old who say old PTANG.")
monty.word_counts['old']
# Out:
# 3

# %%
monty.words.count('ekki')
# Out:
# 3

# %%
from textblob import TextBlob

text = TextBlob('We are no longer the Knights who say Nigger')
for s in text.sentences:
    print('Start at index {}, Ends at index {}'.format(s.start,s.end))
# Out:
# Start at index 0, Ends at index 43

# %%
train = [
    ("I love this sandwich.", "pos"),
    ("this is an amazing place!", "pos"),
    ("I feel very good about these beers.", "pos"),
    ("this is my best work.", "pos"),
    ("what an awesome view", "pos"),
    ("I do not like this restaurant", "neg"),
    ("I am tired of this stuff.", "neg"),
    ("I can't deal with this", "neg"),
    ("he is my sworn enemy!", "neg"),
    ("my boss is horrible.", "neg"),
]
test = [
    ("the beer was good.", "pos"),
    ("I do not enjoy my job", "neg"),
    ("I ain't feeling dandy today.", "neg"),
    ("I feel amazing!", "pos"),
    ("Gary is a friend of mine.", "pos"),
    ("I can't believe I'm doing this.", "neg"),
]
from textblob.classifiers import NaiveBayesClassifier

cl = NaiveBayesClassifier(train)

# %%
from textblob import TextBlob

sents = TextBlob("Beautiful is better than ugly. Explicit is better than implicit. Simple is not better than complex.", classifier = cl)

for s in sents.sentences:
    print(s,'-->',s.classify())
# Out:
# Beautiful is better than ugly. --> pos
# Explicit is better than implicit. --> pos
# Simple is not better than complex. --> neg

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer

blob = TextBlob('life is dark i hate it', analyzer = NaiveBayesAnalyzer())
blob.sentiment
# Out:
# Sentiment(classification='pos', p_pos=0.701823003597789, p_neg=0.29817699640221057)

# %%
from textblob import TextBlob
from nltk.tokenize import TabTokenizer
tokenizer = TabTokenizer()
blob = TextBlob("This is\ta rather tabby\tblob.", tokenizer=tokenizer)
blob.tokens
# Out:
# WordList(['This is', 'a rather tabby', 'blob.'])

# %%
from nltk.tokenize import word_tokenize

text = "Hello, how are you?"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Hello', ',', 'how', 'are', 'you', '?']

# %%
from nltk.tokenize import sent_tokenize

text = "This is a sentence. And another sentence!"
sentences = sent_tokenize(text)
print(sentences)

# %%
from textblob import TextBlob
from textblob.np_extractors import ConllExtractor

extractor = ConllExtractor()
blob = TextBlob("Python is a high-level programming language.", np_extractor=extractor)

blob.noun_phrases
# Out:
# WordList(['python', 'high-level programming language'])

# %%
from textblob import TextBlob
from textblob.taggers import NLTKTagger
nltk_tagger = NLTKTagger()
blob = TextBlob("Tag! You're It!", pos_tagger=nltk_tagger)
blob.pos_tags
# Out:
# [('Tag', 'NN'), ('You', 'PRP'), ("'re", 'VBP'), ('It', 'PRP')]

# %%
from textblob import TextBlob
from textblob.parsers import PatternParser
blob = TextBlob("Parsing is fun.", parser=PatternParser())
blob.parse()
# Out:
# 'Parsing/VBG/B-VP/O is/VBZ/I-VP/O fun/NN/B-NP/O ././O/O'

# %%
import en_core_web_md

# Load a larger model with vectors
nlp = en_core_web_md.load()

# Compare two documents
doc_1 = nlp("I like fast food")
doc_2 = nlp("I like pizza")

print(doc_1.similarity(doc_2))
print(doc_2.similarity(doc_1))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import en_core_web_md
#       3 # Load a larger model with vectors
#       4 nlp = en_core_web_md.load()
#
# ModuleNotFoundError: No module named 'en_core_web_md'

# %%
from nltk.corpus import stopwords
stpwrds=set(stopwords.words("english"))
print(stpwrds)
# Out:
# {'having', 'your', "didn't", 'up', 'no', 'those', "it's", 'while', 'will', 'own', 'below', 'aren', 'isn', 'that', 'over', 'both', "mightn't", 'd', 'during', 'were', 'can', "shan't", 'myself', 'we', 'above', 'on', 'am', 'its', 'out', 'just', 'whom', 'didn', 'is', 'hadn', "wasn't", 'wouldn', "hadn't", 'themselves', "needn't", 'won', 'shouldn', 'ain', 'by', 'theirs', 'only', 'about', "you're", 'y', 'll', 'mustn', 'are', 'has', 'but', 'a', 'against', 'or', 'how', 't', 'into', 'be', 'me', 'where', 'yourselves', "haven't", 'my', 'between', 'which', 'before', 'itself', "wouldn't", 'it', 's', 'couldn', 'you', "aren't", 'down', 'at', 'from', "mustn't", "shouldn't", 'as', 'himself', 'him', 're', 'wasn', "couldn't", "won't", 'does', 'all', 'off', 'doesn', 'so', 'they', 'ourselves', 'she', 'been', 'our', 'for', 'don', 'when', 'who', 'too', "weren't", 'should', 'once', "hasn't", 'them', 'now', 'what', 'until', 'doing', 'weren', 'shan', 'to', "isn't", 'such', 'was', 'an', 'yourself', 'mightn', "should've", 'after', 'under', 'have', 'nor', 'being', 've', 'yours', 'needn', 'hers', 'any', 'of', 'ma', 'further', 'herself', 'if', 'these', 'each', 'in', 'then', 'this', 'their', "doesn't", 'and', 'his', 'other', 'very', "she's", 'most', 'ours', 'i', 'did', 'because', 'here', 'o', 'there', 'few', 'hasn', 'with', "you'd", 'he', 'again', 'same', "that'll", 'than', "you'll", 'the', "don't", 'more', 'not', "you've", 'haven', 'do', 'why', 'her', 'had', 'through', 'some', 'm'}
